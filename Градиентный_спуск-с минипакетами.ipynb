# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name = "/media/art/Terminator/datasets/boston/boston_data.csv"
data = np.genfromtxt(file_name, skip_header=1, delimiter=',')

# %%
Y = data[:, -1]
x = data[:, :-1]

# %%
X = np.zeros(shape=(len(Y), 1 + len(x[0])))
X[:, 0] = 1

# %%
X[:, 1:] = data[:, :-1]

# %%
X_initial = X.copy()
Y_initial = Y.copy()

# %%
def func_gradient(f, x0, dx=0.00001):
    our_gradient = []
    x = list(x0)
    f1 = f(x)
    for i in range(0, len(x)):
        x[i] += dx
        f2 = f(x)
        x[i] -= dx
        our_gradient.append((f2 - f1) / dx)
        
    return our_gradient

# %%
def cost(weights):    
    hyp = (X * weights).sum(axis=1)
    return ((hyp - Y)**2).mean()

# %%
def full_cost(weights):    
    hyp = (X_initial * weights).sum(axis=1)
    return ((hyp - Y_initial)**2).mean()

# %%
# Инициализируем веса нулями для начала
weights = np.array([0] * 14)
# or 
weights = [0] * 14

# %%
cost(weights)
# Out:
# 575.7417326732673

# %%
N = 1000000
error = cost(weights)
error
# Out:
# 575.7417326732673

# %%
X_initial = X.copy()
Y_initial = Y.copy()

# %%
X_initial.shape
# Out:
# (404, 14)

# %%
grad_0 = func_gradient(cost, weights)
grad_0
# Out:
# [-44.62474247475256,
#  -103.26578222930037,
#  -607.2608754720932,
#  -439.0663934941585,
#  -3.726731972619745,
#  -23.934568298500377,
#  -289.3447151905093,
#  -2867.875674485276,
#  -179.41195042112665,
#  -372.99033301678713,
#  -16874.145864994716,
#  -803.8857597739478,
#  -16443.317342248065,
#  -471.5445481338065]

# %% [markdown]
# # Основной цикл обучения

# %%
np.random.normal(0, 1, size=14)
# Out:
# array([ 0.21735714,  0.0341744 , -1.46671903, -0.92971239, -0.67292003,
#        -0.97067414, -1.10912249, -0.6953996 ,  0.05791427,  0.25702656,
#        -0.68039113,  0.77901476,  1.70561506,  0.50031807])

# %%
weights = [0] * 14

# %%
with open("error.log", "w") as f:
        f.write("")

# %%
mini_batch_len = 400

# Learning rate
lr = 0.000003

# %%
good_weights = weights.copy()

# %%
weights = good_weights.copy()

# %%
N = 1000000
for i in range(N):
    
    for mini_batch_i in range(len(X_initial) // mini_batch_len):
        X = X_initial[mini_batch_i * mini_batch_len: (mini_batch_i + 1) * mini_batch_len].copy()
        Y = Y_initial[mini_batch_i * mini_batch_len: (mini_batch_i + 1) * mini_batch_len].copy()
        grad = func_gradient(cost, weights)
        weights = [w - lr* gr for w, gr in zip(weights, grad)]

    # Вывод логов
    if i % 1500 == 0:
        error = full_cost(weights)
        print(error)
        with open("error.log", "a") as f:
            f.write(str(error) + "\n")
# Out:
# 466.0944687738236
# 59.88514779551806
# 55.135295384124426
# 52.00897064830684
# 49.79076725995922
# 48.13137141618259
# 46.83683202792212
# 45.792355413794304
# 44.92631343414912
# 44.191942394669944
# 43.557492007253444
# 43.000653755857144
# 42.505273360602935
# 42.059339928075296
# 41.653716904953036
# 41.281318070697296
# 40.93655783821535
# 40.61497474152701
# 40.312966788813085
# 40.027600737297156
# 39.75647137152193
# 39.49759542618092
# 39.24933009809413
# 39.01030942606879
# 38.77939394547382
# 38.555630405520276
# 38.33821925018826
# 38.12648817971189
# 37.919870534137765
# 37.71788754006006
# 37.520133677692534
# 37.326264584768175
# 37.13598703361448
# 36.94905060950755
# 36.765240789801574
# 36.58437317949568
# 36.406288703693356
# 36.23084959328491
# 36.05793602927793
# 35.88744333477619
# 35.71927962288691
# 35.55336382465235
# 35.38962403405489
# 35.22799611784525
# 35.06842254676787
# 34.91085141203408
# 34.75523559695937
# 34.60153207864138
# 34.44970133875628
# 34.29970686595671
# 34.15151473526011
# 34.00509325217407
# 33.86041265131489
# 33.717444840929524
# 33.57616318610977
# 33.43654232465049
# 33.29855801047226
# 33.16218698032937
# 33.02740684021241
# 32.894195968412674
# 32.76253343270131
# 32.63239891946749
# 32.50377267300327
# 32.37663544338988
# 32.25096844171279
# 32.12675330147869
# 32.003972045333924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-188-228933a818ac> in <module>
#       5         X = X_initial[mini_batch_i * mini_batch_len: (mini_batch_i + 1) * mini_batch_len].copy()
#       6         Y = Y_initial[mini_batch_i * mini_batch_len: (mini_batch_i + 1) * mini_batch_len].copy()
# ----> 7         grad = func_gradient(cost, weights)
#       8         weights = [w - lr* gr for w, gr in zip(weights, grad)]
#       9
#
# <ipython-input-173-1478a488bc0d> in func_gradient(f, x0, dx)
#       5     for i in range(0, len(x)):
#       6         x[i] += dx
# ----> 7         f2 = f(x)
#       8         x[i] -= dx
#       9         our_gradient.append((f2 - f1) / dx)
#
# <ipython-input-174-9ce433fa79ba> in cost(weights)
#       1 def cost(weights):
# ----> 2     hyp = (X * weights).sum(axis=1)
#       3     return ((hyp - Y)**2).mean()
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %% [markdown]
# # Mean Average Error

# %%
hyp = (X_initial * weights).sum(axis=1)

# %%
print("В среднем предсказанная цена отличается от истинной на", (np.abs(hyp - Y_initial)).mean())

# %%
print("Истинная и предсказанная цена")
list(zip(Y_initial, hyp))

# %%
full_cost(weights)

# %% [markdown]
# ## Провека с помощью sklearn

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
result = lm.fit(X, Y)
print(result.coef_)
print(result.intercept_)
# Out:
# [ 0.00000000e+00 -1.19620247e-01  3.59138705e-02  1.11761084e-02
#   1.35251083e+00 -1.49825657e+01  3.96100031e+00 -4.74442414e-03
#  -1.30862947e+00  2.75527372e-01 -1.26957841e-02 -9.19447921e-01
#   8.51564749e-03 -5.12290083e-01]
# 33.73868632512524

# %%
predicted = lm.predict(X_initial)

# %%
print("В среднем предсказанная цена отличается от истинной на", (np.abs(predicted - Y_initial)).mean())
# Out:
# В среднем предсказанная цена отличается от истинной на 3.075606332635659

# %%
list(zip(Y_initial, predicted))
# Out:
# [(21.7, 21.98704570055698),
#  (19.6, 21.21794054783121),
#  (20.3, 23.479649691723754),
#  (15.4, 15.056518187866132),
#  (20.5, 24.072400512153596),
#  (34.9, 34.10269709349327),
#  (26.2, 24.568922216560427),
#  (21.6, 25.45121237938054),
#  (14.1, 18.062939093441834),
#  (17.0, 21.35649379642755),
#  (10.4, 6.116802899010537),
#  (23.3, 28.387613817568003),
#  (21.0, 21.120140532394934),
#  (22.2, 24.10625798507718),
#  (8.7, 8.540737600216548),
#  (23.7, 26.275405918131472),
#  (22.2, 24.18045725604434),
#  (12.0, 10.542370143723087),
#  (21.5, 21.07648042036122),
#  (23.3, 25.79986256129533),
#  (9.5, 12.658203517462194),
#  (23.0, 19.94302534034905),
#  (20.8, 23.239612099837604),
#  (29.4, 30.763137693633787),
#  (16.5, 22.604639070352427),
#  (16.2, 20.54399125282515),
#  (18.4, 18.166621560796877),
#  (31.1, 32.00505818373615),
#  (21.9, 23.926935103314733),
#  (18.6, 17.35729561614091),
#  (29.1, 31.378404218259366),
#  (36.2, 27.63688422204187),
#  (21.7, 24.510939949799823),
#  (17.8, 17.72021204973664),
#  (5.0, 5.439285381078651),
#  (23.1, 25.042248918991522),
#  (50.0, 36.09964180495813),
#  (29.0, 30.309569472917588),
#  (12.7, 12.51179785792172),
#  (35.1, 35.127329922468235),
#  (19.9, 18.570503652939205),
#  (13.8, 12.548623631357756),
#  (23.9, 26.854671777245088),
#  (20.2, 21.933876088831703),
#  (22.6, 18.856194739596994),
#  (19.4, 17.497368418713272),
#  (19.9, 19.409314783257035),
#  (15.6, 19.32954004597842),
#  (43.1, 36.96720962414406),
#  (13.4, 13.145939247632818),
#  (13.1, 14.887870909875776),
#  (11.3, 12.6139527574318),
#  (31.0, 34.22250675004561),
#  (42.3, 36.75824930556482),
#  (44.8, 38.26777674648025),
#  (25.0, 27.784105326198247),
#  (35.2, 34.26345179758094),
#  (34.9, 29.80119349166833),
#  (24.0, 25.150944191529423),
#  (18.2, 19.475224273885907),
#  (10.2, 15.89111412009435),
#  (17.8, 22.084101525599007),
#  (7.2, 9.148659678456767),
#  (28.2, 32.21562228469901),
#  (22.9, 28.544357746030183),
#  (34.7, 30.850597856227015),
#  (22.0, 28.71283412361711),
#  (22.4, 21.424219092345016),
#  (17.1, 19.212096312529166),
#  (22.0, 26.16708574310217),
#  (24.1, 28.686702297343682),
#  (50.0, 30.267681169427394),
#  (21.7, 20.652743557062248),
#  (19.8, 22.393093008683408),
#  (33.4, 35.11898499357462),
#  (25.0, 22.27397044781326),
#  (22.0, 27.326374001933534),
#  (8.5, 15.52455600574931),
#  (23.2, 26.873471967928076),
#  (16.8, 18.413564306956456),
#  (18.2, 18.515576270634682),
#  (17.1, 16.772439221806145),
#  (20.6, 20.664444699554497),
#  (16.4, 18.745338407757657),
#  (19.9, 17.512160306572255),
#  (43.5, 39.180382016130324),
#  (21.6, 25.15679684141029),
#  (20.0, 22.71826571748727),
#  (50.0, 40.73103816160297),
#  (23.1, 9.594248368937507),
#  (20.6, 22.576794633975748),
#  (13.5, 12.708054101087122),
#  (12.7, 11.662509906806605),
#  (18.5, 24.81711949027295),
#  (13.1, 19.571912016934416),
#  (23.4, 24.361917483644973),
#  (18.4, 19.76819052578856),
#  (35.4, 34.33861286331698),
#  (19.3, 15.591543554175377),
#  (12.6, 17.563063289803743),
#  (26.6, 28.617032621579273),
#  (32.9, 30.392291675250394),
#  (39.8, 34.72746964423842),
#  (29.6, 25.652860513513637),
#  (30.1, 29.481546154595947),
#  (14.0, 13.490750707414495),
#  (24.5, 27.51333660380703),
#  (32.7, 30.59398497174866),
#  (41.3, 32.81790712846514),
#  (28.7, 25.656622749880864),
#  (19.0, 21.618984986372297),
#  (30.1, 25.799386278786212),
#  (34.6, 34.37472635653273),
#  (15.6, 12.34485985600567),
#  (5.0, 6.694214234666447),
#  (20.1, 21.17248650772974),
#  (8.5, 6.353429972367319),
#  (23.8, 25.47852904086339),
#  (23.8, 25.08240554258892),
#  (15.1, 16.446234912272416),
#  (16.1, 18.439022852341456),
#  (21.8, 20.556886655024122),
#  (13.9, 13.632122522616903),
#  (30.8, 30.957982857615917),
#  (11.8, 8.890917374340333),
#  (15.6, 15.844106826970101),
#  (23.7, 11.508499589026997),
#  (23.2, 25.62988402184167),
#  (28.4, 30.357479057316613),
#  (18.9, 23.703982572632267),
#  (21.4, 24.621766021432933),
#  (26.4, 22.48401745447699),
#  (23.8, 26.032232937694804),
#  (36.2, 28.475519455520967),
#  (16.1, 18.073759255885694),
#  (37.2, 32.924409678271736),
#  (21.7, 22.189493929156786),
#  (24.8, 26.894380158062873),
#  (20.8, 17.54705376402112),
#  (14.5, 18.144145568228122),
#  (12.3, 12.263567616779824),
#  (17.2, 16.222733624200842),
#  (18.9, 21.705955093933948),
#  (10.5, 5.044008973695721),
#  (7.0, 7.828423852622862),
#  (24.7, 23.10433782189198),
#  (16.1, 20.891027066303664),
#  (37.9, 33.71030655744848),
#  (21.9, 35.905756633884316),
#  (19.1, 16.154589773261677),
#  (24.4, 22.279053080511456),
#  (19.6, 19.27431068094023),
#  (23.0, 22.672451730522486),
#  (20.5, 20.03800757260282),
#  (25.0, 27.989478980811423),
#  (13.5, 13.933089205345535),
#  (37.6, 37.4424863644261),
#  (29.8, 31.95815920530526),
#  (13.4, 13.445895190713728),
#  (12.1, 17.539799760251373),
#  (50.0, 42.51033102303573),
#  (24.1, 21.021548318136055),
#  (20.0, 22.29386651858589),
#  (19.6, 17.77444110112779),
#  (21.0, 23.2151468596748),
#  (21.7, 21.03572362720311),
#  (27.5, 30.632453187340232),
#  (8.8, 2.3628018764906464),
#  (21.9, 14.776509951563185),
#  (18.9, 19.13860971099414),
#  (8.4, 4.670170629083248),
#  (22.7, 24.354400010739873),
#  (20.2, 16.510742396387716),
#  (12.7, 17.085290835574217),
#  (22.4, 23.708357142909136),
#  (28.7, 28.248723264396464),
#  (26.6, 22.78607235957108),
#  (11.9, 6.74409574495651),
#  (21.1, 22.290537217495555),
#  (13.9, 16.9631239463454),
#  (27.5, 18.996489711536544),
#  (15.2, 18.94704238337743),
#  (18.7, 20.39916904207488),
#  (21.7, 21.15249587577523),
#  (10.2, 15.705636845662283),
#  (20.0, 20.70831926365019),
#  (25.0, 28.758348824068797),
#  (26.5, 25.53878275318681),
#  (19.4, 19.573130889735456),
#  (22.6, 26.245490540166468),
#  (11.5, 13.380219183571619),
#  (22.2, 19.746394107728047),
#  (30.3, 32.37811548835158),
#  (18.8, 20.342801800802928),
#  (30.1, 34.60038765000762),
#  (19.4, 17.559436805967763),
#  (11.8, 12.972803690319896),
#  (28.6, 28.725123413938025),
#  (27.0, 30.87059969396091),
#  (20.3, 22.367603089944033),
#  (50.0, 43.21062430142389),
#  (20.1, 23.577437386411958),
#  (33.1, 33.352545086642635),
#  (17.2, 12.730845126442635),
#  (23.1, 22.590844721069224),
#  (26.7, 31.55908186598978),
#  (13.3, 15.301572396807014),
#  (21.4, 20.861753250394727),
#  (19.1, 18.9782068176892),
#  (9.7, 9.048008700414382),
#  (36.5, 35.55111827064593),
#  (23.4, 24.342802095709878),
#  (33.3, 35.78709561813754),
#  (24.6, 25.19062839557124),
#  (11.7, 13.971694361133238),
#  (20.5, 20.38625831801908),
#  (23.9, 27.63519655236469),
#  (13.0, 16.732788334372323),
#  (15.3, 18.91296493751837),
#  (22.6, 22.874546752652886),
#  (19.6, 18.427782471689174),
#  (8.1, 3.3241972678122416),
#  (19.6, 22.03182388345856),
#  (13.4, 12.697392948242673),
#  (24.8, 30.470381553033203),
#  (16.7, 18.948315670328025),
#  (50.0, 36.41957799380549),
#  (23.6, 28.77729352376479),
#  (32.0, 32.82815632717127),
#  (22.0, 27.29837988909153),
#  (22.9, 20.970580807216827),
#  (17.3, 16.232334283398473),
#  (23.1, 25.188302999417374),
#  (18.5, 19.508714156828358),
#  (27.5, 13.172934998880542),
#  (20.0, 18.008672721653046),
#  (15.0, 19.224090298593346),
#  (15.4, 17.506332274384953),
#  (33.2, 34.08756004662803),
#  (20.9, 20.984024200440466),
#  (21.2, 21.22919412708898),
#  (13.4, 16.36035779923302),
#  (19.4, 23.082524294840727),
#  (22.3, 26.302661455418452),
#  (19.7, 13.974893221757014),
#  (29.1, 30.03651089422113),
#  (8.4, 14.437261145251892),
#  (20.7, 22.25476489380711),
#  (24.8, 26.048192145956186),
#  (25.0, 25.39276754148789),
#  (23.3, 25.203225592820253),
#  (18.2, 14.684398711993822),
#  (20.6, 16.98244658688705),
#  (24.6, 28.963784372110457),
#  (17.8, 17.8335454927731),
#  (20.3, 19.70553012942369),
#  (24.4, 24.60350364783769),
#  (19.3, 20.582185810127566),
#  (17.9, 0.7919653781957194),
#  (22.9, 24.98677502565535),
#  (10.9, 17.62047954083937),
#  (7.2, 7.193300046585037),
#  (21.2, 21.296345342448447),
#  (25.0, 23.013323707270345),
#  (25.1, 28.705181137965333),
#  (19.3, 22.31445231269482),
#  (22.9, 23.089725006604915),
#  (17.4, 17.609614145827926),
#  (21.8, 20.494363159764973),
#  (24.3, 28.45069095204101),
#  (14.9, 16.83818184918546),
#  (17.5, 17.227854679923983),
#  (50.0, 40.314938374454776),
#  (10.9, 13.3238070223568),
#  (13.8, 19.463928239490343),
#  (23.2, 16.755778251136622),
#  (20.3, 22.327686534485114),
#  (22.8, 28.567100301821267),
#  (14.2, 17.49421442294255),
#  (19.8, 18.49451382257403),
#  (46.7, 35.68271770932914),
#  (15.0, 24.400892501042154),
#  (7.2, 16.999929644254966),
#  (19.1, 23.866453163591235),
#  (21.2, 23.28592745374678),
#  (8.8, 4.895023054827178),
#  (28.1, 25.412609909921525),
#  (33.2, 32.3056082416823),
#  (21.4, 19.78702720990767),
#  (14.8, 15.010472412775762),
#  (13.1, 14.010872149385733),
#  (17.6, 16.43905105109172),
#  (23.9, 25.012845151305736),
#  (17.4, 22.238124547600208),
#  (18.5, 19.709618701004644),
#  (13.3, 13.63263215927666),
#  (19.9, 19.57336710255033),
#  (21.7, 20.944296195627874),
#  (21.4, 23.93104698219061),
#  (21.2, 23.169477958685242),
#  (26.6, 27.91917082372251),
#  (22.5, 17.910953881925177),
#  (22.3, 26.988979227755426),
#  (41.7, 38.12418738940435),
#  (8.3, 9.428141396634281),
#  (18.5, 13.606688806332329),
#  (24.1, 25.60121094005621),
#  (26.4, 28.7558841896236),
#  (25.3, 25.70294190550245),
#  (17.4, 15.739430056719293),
#  (14.5, 17.483286533872025),
#  (33.4, 29.134614021105563),
#  (14.1, 15.66771374942742),
#  (14.6, 18.298443200338788),
#  (50.0, 40.402292064334205),
#  (19.5, 16.90599359409054),
#  (11.7, 15.495119111083142),
#  (31.5, 31.25895731854346),
#  (31.7, 33.212612769662975),
#  (42.8, 30.855124370619706),
#  (24.4, 28.358125544361215),
#  (23.5, 29.86833305033855),
#  (30.7, 31.07049057838935),
#  (14.5, 13.914090335947758),
#  (29.0, 31.8369887389279),
#  (12.5, 18.617290381322363),
#  (20.6, 22.394965050793903),
#  (20.4, 23.05423755560776),
#  (22.1, 26.788944047402914),
#  (19.5, 18.191598571974936),
#  (24.8, 25.439844496669213),
#  (20.1, 15.587732645983419),
#  (23.1, 17.089199013411587),
#  (14.9, 15.113425241318467),
#  (27.1, 19.634910201625157),
#  (23.7, 27.63591463203618),
#  (6.3, 10.329759868708486),
#  (28.5, 32.865460152621864),
#  (23.2, 21.752612632796342),
#  (23.1, 24.371162509245202),
#  (27.1, 27.52053035959112),
#  (23.0, 28.16467190893955),
#  (13.6, 13.356406605974222),
#  (29.6, 24.771160965194426),
#  (19.5, 19.30921556994868),
#  (28.0, 28.45748126780498),
#  (33.1, 32.69723635499436),
#  (50.0, 23.82011820330416),
#  (27.5, 24.478954141289417),
#  (36.0, 36.16683671950585),
#  (32.5, 30.739701444663638),
#  (17.8, 16.269739918355494),
#  (50.0, 36.92034235439452),
#  (22.0, 21.367342593365738),
#  (13.1, 14.356904624270609),
#  (9.6, 14.229238257014039),
#  (20.4, 20.121690210824767),
#  (31.2, 28.574842469474216),
#  (24.5, 21.61483270679479),
#  (33.0, 24.14063637486989),
#  (29.9, 31.283044603628316),
#  (22.2, 22.829610012274415),
#  (19.8, 21.960878297476945),
#  (16.5, 11.683369876731401),
#  (18.7, 21.719244245798244),
#  (19.1, 16.150927567219508),
#  (15.7, 14.451503340487097),
#  (24.0, 30.01020042267098),
#  (22.6, 27.085587856182602),
#  (20.7, 24.188734768606427),
#  (28.7, 30.925886534185445),
#  (17.8, 10.001204399590861),
#  (18.7, 17.973048195565173),
#  (29.8, 25.000005003057005),
#  (11.0, 13.897161091555116),
#  (19.3, 21.42521037665947),
#  (24.7, 25.127047638937544),
#  (5.6, 10.97322273925909),
#  (20.8, 17.600899921180872),
#  (10.2, 5.5874992866093045),
#  (10.4, 12.70264601714469),
#  (30.5, 30.170102567998644),
#  (50.0, 32.21821601345401),
#  (14.3, 16.764488775509385),
#  (14.4, 9.331547508011873),
#  (21.2, 21.772373358598955),
#  (13.3, 19.46098795069371),
#  (18.9, 15.120087835841694),
#  (48.3, 37.237223167142666),
#  (24.4, 23.83874375726035),
#  (23.1, 20.944999677930095),
#  (23.9, 27.45519969849531),
#  (24.2, 25.530067199372134),
#  (34.9, 33.883679234983916),
#  (23.9, 26.02401872423588),
#  (22.5, 22.338365747402314),
#  (22.0, 21.833170658599833),
#  (22.8, 26.31640008969411),
#  (16.6, 15.676994063740764),
#  (14.1, 16.889830264293817),
#  (15.0, 13.786752656892162),
#  (50.0, 42.89776614050358),
#  (24.7, 24.83962238435742),
#  (23.7, 28.486337007289528)]
